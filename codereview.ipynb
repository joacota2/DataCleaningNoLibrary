# %%
import os
archivo=open('Emisiones_CO2.csv','r')

# %%
dicc_emisiones = {  'cod_pais' : [],
                    'nom_pais' : [],
                    'region' : [],
                    'anio' : [],
                    'co2' : [],
                    'co2_percapita' : []}

# %%
encabezado=True

for linea in archivo:
    if not encabezado:
        campos=linea.split(sep='|')
        dicc_emisiones['cod_pais'].append(campos[0])
        dicc_emisiones['nom_pais'].append(campos[1])
        dicc_emisiones['region'].append(campos[2])
        dicc_emisiones['anio'].append(campos[3])
        dicc_emisiones['co2'].append(campos[4])
        dicc_emisiones['co2_percapita'].append(campos[5])
    else:
        encabezado = False

# %%
archivo.close()
dicc_emisiones['cod_pais']
# Out:
# ['ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AFG',
#  'AFG',
#  'AFG',
#  'AFG',
#  'AFG',
#  'AFG',
#  'AFG',
#  'AFG',
#  'AFG',
#  'AFG',
#  'AFG',
#  'AFG',
#  'AFG',
#  'AFG',
#  'AFG',
#  'AFG',
#  'AFG',
#  'AFG',
#  'AFG',
#  'AFG',
#  'AFG',
#  'AFG',
#  'AFG',
#  'AFG',
#  'AFG',
#  'AFG',
#  'AFG',
#  'AFG',
#  'AFG',
#  'AFG',
#  'AFG',
#  'AFG',
#  'AFG',
#  'AFG',
#  'AFG',
#  'AFG',
#  'AFG',
#  'AFG',
#  'AFG',
#  'AFG',
#  'AFG',
#  'AFG',
#  'AFG',
#  'AFG',
#  'AFG',
#  'AFG',
#  'AFG',
#  'AFG',
#  'AFG',
#  'AFG',
#  'AFG',
#  'AFG',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'ALB',
#  'ALB',
#  'ALB',
#  'ALB',
#  'ALB',
#  'ALB',
#  'ALB',
#  'ALB',
#  'ALB',
#  'ALB',
#  'ALB',
#  'ALB',
#  'ALB',
#  'ALB',
#  'ALB',
#  'ALB',
#  'ALB',
#  'ALB',
#  'ALB',
#  'ALB',
#  'ALB',
#  'ALB',
#  'ALB',
#  'ALB',
#  'ALB',
#  'ALB',
#  'ALB',
#  'ALB',
#  'ALB',
#  'ALB',
#  'ALB',
#  'ALB',
#  'ALB',
#  'ALB',
#  'ALB',
#  'ALB',
#  'ALB',
#  'ALB',
#  'ALB',
#  'ALB',
#  'ALB',
#  'ALB',
#  'ALB',
#  'ALB',
#  'ALB',
#  'ALB',
#  'ALB',
#  'ALB',
#  'ALB',
#  'ALB',
#  'ALB',
#  'ALB',
#  'ARE',
#  'ARE',
#  'ARE',
#  'ARE',
#  'ARE',
#  'ARE',
#  'ARE',
#  'ARE',
#  'ARE',
#  'ARE',
#  'ARE',
#  'ARE',
#  'ARE',
#  'ARE',
#  'ARE',
#  'ARE',
#  'ARE',
#  'ARE',
#  'ARE',
#  'ARE',
#  'ARE',
#  'ARE',
#  'ARE',
#  'ARE',
#  'ARE',
#  'ARE',
#  'ARE',
#  'ARE',
#  'ARE',
#  'ARE',
#  'ARE',
#  'ARE',
#  'ARE',
#  'ARE',
#  'ARE',
#  'ARE',
#  'ARE',
#  'ARE',
#  'ARE',
#  'ARE',
#  'ARE',
#  'ARE',
#  'ARE',
#  'ARE',
#  'ARE',
#  'ARE',
#  'ARE',
#  'ARE',
#  'ARE',
#  'ARE',
#  'ARE',
#  'ARE',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARM',
#  'ARM',
#  'ARM',
#  'ARM',
#  'ARM',
#  'ARM',
#  'ARM',
#  'ARM',
#  'ARM',
#  'ARM',
#  'ARM',
#  'ARM',
#  'ARM',
#  'ARM',
#  'ARM',
#  'ARM',
#  'ARM',
#  'ARM',
#  'ARM',
#  'ARM',
#  'ARM',
#  'ARM',
#  'ARM',
#  'ARM',
#  'ARM',
#  'ARM',
#  'ARM',
#  'ARM',
#  'ARM',
#  'ARM',
#  'ARM',
#  'ARM',
#  'ARM',
#  'ARM',
#  'ARM',
#  'ARM',
#  'ARM',
#  'ARM',
#  'ARM',
#  'ARM',
#  'ARM',
#  'ARM',
#  'ARM',
#  'ARM',
#  'ARM',
#  'ARM',
#  'ARM',
#  'ARM',
#  'ARM',
#  'ARM',
#  'ARM',
#  'ARM',
#  'ASM',
#  'ASM',
#  'ASM',
#  'ASM',
#  'ASM',
#  'ASM',
#  'ASM',
#  'ASM',
#  'ASM',
#  'ASM',
#  'ASM',
#  'ASM',
#  'ASM',
#  'ASM',
#  'ASM',
#  'ASM',
#  'ASM',
#  'ASM',
#  'ASM',
#  'ASM',
#  'ASM',
#  'ASM',
#  'ASM',
#  'ASM',
#  'ASM',
#  'ASM',
#  'ASM',
#  'ASM',
#  'ASM',
#  'ASM',
#  'ASM',
#  'ASM',
#  'ASM',
#  'ASM',
#  'ASM',
#  'ASM',
#  'ASM',
#  'ASM',
#  'ASM',
#  'ASM',
#  'ASM',
#  'ASM',
#  'ASM',
#  'ASM',
#  'ASM',
#  'ASM',
#  'ASM',
#  'ASM',
#  'ASM',
#  'ASM',
#  'ASM',
#  'ASM',
#  'ATG',
#  'ATG',
#  'ATG',
#  'ATG',
#  'ATG',
#  'ATG',
#  'ATG',
#  'ATG',
#  'ATG',
#  'ATG',
#  'ATG',
#  'ATG',
#  'ATG',
#  'ATG',
#  'ATG',
#  'ATG',
#  'ATG',
#  'ATG',
#  'ATG',
#  'ATG',
#  'ATG',
#  'ATG',
#  'ATG',
#  'ATG',
#  'ATG',
#  'ATG',
#  'ATG',
#  'ATG',
#  'ATG',
#  'ATG',
#  'ATG',
#  'ATG',
#  'ATG',
#  'ATG',
#  'ATG',
#  'ATG',
#  'ATG',
#  'ATG',
#  'ATG',
#  'ATG',
#  'ATG',
#  'ATG',
#  'ATG',
#  'ATG',
#  'ATG',
#  'ATG',
#  'ATG',
#  'ATG',
#  'ATG',
#  'ATG',
#  'ATG',
#  'ATG',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AZE',
#  'AZE',
#  'AZE',
#  'AZE',
#  'AZE',
#  'AZE',
#  'AZE',
#  'AZE',
#  'AZE',
#  'AZE',
#  'AZE',
#  'AZE',
#  'AZE',
#  'AZE',
#  'AZE',
#  'AZE',
#  'AZE',
#  'AZE',
#  'AZE',
#  'AZE',
#  'AZE',
#  'AZE',
#  'AZE',
#  'AZE',
#  'AZE',
#  'AZE',
#  'AZE',
#  'AZE',
#  'AZE',
#  'AZE',
#  'AZE',
#  'AZE',
#  'AZE',
#  'AZE',
#  'AZE',
#  'AZE',
#  'AZE',
#  'AZE',
#  'AZE',
#  'AZE',
#  'AZE',
#  'AZE',
#  'AZE',
#  'AZE',
#  'AZE',
#  'AZE',
#  'AZE',
#  'AZE',
#  'AZE',
#  'AZE',
#  'AZE',
#  'AZE',
#  'BDI',
#  'BDI',
#  'BDI',
#  'BDI',
#  'BDI',
#  'BDI',
#  'BDI',
#  'BDI',
#  'BDI',
#  'BDI',
#  'BDI',
#  'BDI',
#  'BDI',
#  'BDI',
#  'BDI',
#  'BDI',
#  'BDI',
#  'BDI',
#  'BDI',
#  'BDI',
#  'BDI',
#  'BDI',
#  'BDI',
#  'BDI',
#  'BDI',
#  'BDI',
#  'BDI',
#  'BDI',
#  'BDI',
#  'BDI',
#  'BDI',
#  'BDI',
#  'BDI',
#  'BDI',
#  'BDI',
#  'BDI',
#  'BDI',
#  'BDI',
#  'BDI',
#  'BDI',
#  'BDI',
#  'BDI',
#  'BDI',
#  'BDI',
#  'BDI',
#  'BDI',
#  'BDI',
#  'BDI',
#  'BDI',
#  'BDI',
#  'BDI',
#  'BDI',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEN',
#  'BEN',
#  'BEN',
#  'BEN',
#  'BEN',
#  'BEN',
#  'BEN',
#  'BEN',
#  'BEN',
#  'BEN',
#  'BEN',
#  'BEN',
#  'BEN',
#  'BEN',
#  'BEN',
#  'BEN',
#  'BEN',
#  'BEN',
#  'BEN',
#  'BEN',
#  'BEN',
#  'BEN',
#  'BEN',
#  'BEN',
#  'BEN',
#  'BEN',
#  'BEN',
#  'BEN',
#  'BEN',
#  'BEN',
#  'BEN',
#  'BEN',
#  'BEN',
#  'BEN',
#  'BEN',
#  'BEN',
#  'BEN',
#  'BEN',
#  'BEN',
#  'BEN',
#  'BEN',
#  'BEN',
#  'BEN',
#  'BEN',
#  'BEN',
#  'BEN',
#  'BEN',
#  'BEN',
#  'BEN',
#  'BEN',
#  'BEN',
#  'BEN',
#  'BFA',
#  'BFA',
#  'BFA',
#  'BFA',
#  'BFA',
#  'BFA',
#  'BFA',
#  'BFA',
#  'BFA',
#  'BFA',
#  'BFA',
#  'BFA',
#  'BFA',
#  'BFA',
#  'BFA',
#  'BFA',
#  'BFA',
#  'BFA',
#  'BFA',
#  'BFA',
#  'BFA',
#  'BFA',
#  'BFA',
#  'BFA',
#  'BFA',
#  'BFA',
#  'BFA',
#  'BFA',
#  'BFA',
#  'BFA',
#  'BFA',
#  'BFA',
#  'BFA',
#  'BFA',
#  'BFA',
#  'BFA',
#  'BFA',
#  'BFA',
#  'BFA',
#  'BFA',
#  'BFA',
#  'BFA',
#  'BFA',
#  'BFA',
#  'BFA',
#  'BFA',
#  'BFA',
#  'BFA',
#  'BFA',
#  'BFA',
#  'BFA',
#  'BFA',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BHR',
#  'BHR',
#  'BHR',
#  'BHR',
#  'BHR',
#  'BHR',
#  'BHR',
#  'BHR',
#  'BHR',
#  'BHR',
#  'BHR',
#  'BHR',
#  ...]

# %%
#Cuantas variables hay
len(campos)
# Out:
# 6

# %%
i=0
print(dicc_emisiones['cod_pais'][i])
print(dicc_emisiones['nom_pais'][i])
print(dicc_emisiones['region'][i])
print(dicc_emisiones['anio'][i])
print(dicc_emisiones['co2'][i])
print(dicc_emisiones['co2_percapita'][i])
# Out:
# ABW
# Aruba
# América Latina y Caribe
# 1960

# %%
for indice, elemento in enumerate(dicc_emisiones['co2']):
    elemento=elemento.replace('\n','')
    elemento=elemento.replace('.','')
    elemento=elemento.replace(',','.')
    if elemento != '':
        elemento=float(elemento)
    else:
        elemento=None
    dicc_emisiones['co2_percapita'][indice]=elemento

# %%
dicc_emisiones.keys()
# Out:
# dict_keys(['cod_pais', 'nom_pais', 'region', 'anio', 'co2', 'co2_percapita'])

# %%
print(f'Hay {len(dicc_emisiones.keys())} variables')
print(f'Los tipos de variables son: {[type(i[100]) for i in dicc_emisiones.values()]}')
valores_falt=False
for i in  dicc_emisiones.values():
    if None in i:
        valores_falt=True
        break
    else:
        pass
if valores_falt==True:
    print('Hay valores faltantes')
else:
    print('No hay faltantes')
# Out:
# Hay 6 variables
# Los tipos de variables son: [<class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'float'>]
# Hay valores faltantes

# %%
filtro_region='América Latina y Caribe'
filtro_anio='2010'
emisiones=0
for indice, elemento in enumerate(dicc_emisiones['region']):
    if dicc_emisiones['region'][indice] == filtro_region:
        if dicc_emisiones['anio'][indice]==filtro_anio:
            if dicc_emisiones['co2'][indice]!=None:
                emisiones += dicc_emisiones['co2'][indice]
print('Las emisiones en',filtro_region,'en',filtro_anio,'fueron de',emisiones,'kt')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\gomez\Desktop\Henry\Repos clases\Clase 02\codereview.ipynb Cell 10' in <cell line: 4>()
#       <a href='vscode-notebook-cell:/c%3A/Users/gomez/Desktop/Henry/Repos%20clases/Clase%2002/codereview.ipynb#ch0000010?line=5'>6</a>         if dicc_emisiones['anio'][indice]==filtro_anio:
#       <a href='vscode-notebook-cell:/c%3A/Users/gomez/Desktop/Henry/Repos%20clases/Clase%2002/codereview.ipynb#ch0000010?line=6'>7</a>             if dicc_emisiones['co2'][indice]!=None:
# ----> <a href='vscode-notebook-cell:/c%3A/Users/gomez/Desktop/Henry/Repos%20clases/Clase%2002/codereview.ipynb#ch0000010?line=7'>8</a>                 emisiones+=dicc_emisiones['co2'][indice]
#       <a href='vscode-notebook-cell:/c%3A/Users/gomez/Desktop/Henry/Repos%20clases/Clase%2002/codereview.ipynb#ch0000010?line=8'>9</a> print('Las emisiones en',filtro_region,'en',filtro_anio,'fueron de',emisiones,'kt')
#
# TypeError: unsupported operand type(s) for +=: 'int' and 'str'
